# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

import scipy.cluster.hierarchy as shc

# %config InlineBackend.figure_format = "retina"
# %matplotlib inline

# %%
data = pd.read_excel("../data/ssc_case_study_2_inflammatory_bowel_disease.xlsx")

# Cleaning descriptive data (includes group, sex, age, ethnicity)
descriptive_data = data.loc[:3]
descriptive_data.set_index("Other Variables", inplace=True)
del descriptive_data["Probe.Set.ID"]
patient_id = [re.search("SAK_(\d)*", s).group(0) for s in descriptive_data.columns]
descriptive_data = descriptive_data.T
descriptive_data.index = patient_id

# Gene dictionary
matched_genes = pd.read_excel("../data/ssc_case_study_2_inflammatory_bowel_disease.xlsx", sheet_name=1)
matched_genes.set_index("Probe.Set.ID", inplace=True)

# Gene expression data!
data = data.loc[4:]
data.set_index("Probe.Set.ID", inplace=True)
del data["Other Variables"]
data = data.T
data.index = patient_id
data.columns = [matched_genes.loc[probe_set]["Gene.Symbol"] for probe_set in data.columns]

descriptive_data.columns.name = None
data.columns.name = None

# %%
data.head()
# Out:
#                   PARK7    RPS25  S100A11    LITAF    LITAF     ATF4    STAT1  \
# SAK_1286453367  1066.74  3438.65  197.508  1836.72  955.034  2947.25  134.747
# SAK_1313783292  691.849  1754.63  511.376  1921.33  883.717  2900.09  394.819
# SAK_1286475720  1013.81   2837.3  398.176  1363.13  715.678  1841.66  198.923
# SAK_1316845653  1134.79  2805.89   321.68  1202.75  519.659  2389.31  256.781
# SAK_1316800947  1354.32  1956.35  981.175  2276.09  864.242  1709.66  407.023
#
#                     VCL      VCL    ANXA6  ...  TNFSF15    IKZF3      IL26  \
# SAK_1286453367  3.75346  926.592  85.4973  ...  6.98463  2.94378  0.394986
# SAK_1313783292   5.4273  1488.01  51.1361  ...  16.3137     27.6   1.42313
# SAK_1286475720  20.5204   1625.1   200.59  ...   21.289  16.4332   1.49251
# SAK_1316845653  13.3613   1328.1   317.98  ...  7.96777  16.1678   1.27199
# SAK_1316800947  3.88497  2717.56   158.48  ...   11.764  9.42704   1.01882
#
# ...

# %%
descriptive_data.head()
# Out:
#                              Group Age  Ethnicity     Sex
# SAK_1286453367  Ulcerative Colitis  25  caucasian  female
# SAK_1313783292     Crohn's Disease  46  caucasian  female
# SAK_1286475720  Ulcerative Colitis  45  caucasian    male
# SAK_1316845653     Crohn's Disease  46  caucasian  female
# SAK_1316800947     Crohn's Disease  38  caucasian    male

# %%
plt.figure(figsize=(10, 7))
a = shc.dendrogram(shc.linkage(data, method='ward'))

# %%
a
# Out:
# {'icoord': [[5.0, 5.0, 15.0, 15.0],
#   [25.0, 25.0, 35.0, 35.0],
#   [45.0, 45.0, 55.0, 55.0],
#   [30.0, 30.0, 50.0, 50.0],
#   [75.0, 75.0, 85.0, 85.0],
#   [65.0, 65.0, 80.0, 80.0],
#   [105.0, 105.0, 115.0, 115.0],
#   [95.0, 95.0, 110.0, 110.0],
#   [125.0, 125.0, 135.0, 135.0],
#   [145.0, 145.0, 155.0, 155.0],
#   [175.0, 175.0, 185.0, 185.0],
#   [165.0, 165.0, 180.0, 180.0],
#   [150.0, 150.0, 172.5, 172.5],
#   [130.0, 130.0, 161.25, 161.25],
#   [102.5, 102.5, 145.625, 145.625],
#   [72.5, 72.5, 124.0625, 124.0625],
#   [40.0, 40.0, 98.28125, 98.28125],
#   [215.0, 215.0, 225.0, 225.0],
#   [205.0, 205.0, 220.0, 220.0],
#   [195.0, 195.0, 212.5, 212.5],
#   [245.0, 245.0, 255.0, 255.0],
#   [235.0, 235.0, 250.0, 250.0],
#   [203.75, 203.75, 242.5, 242.5],
#   [265.0, 265.0, 275.0, 275.0],
#   [295.0, 295.0, 305.0, 305.0],
#   [285.0, 285.0, 300.0, 300.0],
#   [270.0, 270.0, 292.5, 292.5],
#   [223.125, 223.125, 281.25, 281.25],
#   [325.0, 325.0, 335.0, 335.0],
# ...
